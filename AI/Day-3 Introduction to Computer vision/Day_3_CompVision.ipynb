# %% [markdown]
# <a href="https://colab.research.google.com/github/thogeti/pantech/blob/main/AI/Day-3%20Introduction%20to%20Computer%20vision/Day_3_CompVision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **[AI Pantech]**

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread("sample_data/bus.jpg")
#cv2.imshow("Busimg",img)
#img = cv2.imread('bus.jpg')

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=602x437 at 0x7F45A79D8BD0>
